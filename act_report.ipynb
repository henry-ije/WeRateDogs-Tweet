# %% [markdown]
# #### Act Report

# %% [markdown]
# #### Visualisation and Insights

# %% [markdown]
# - From the visualisation and insights, it has been deduced that most of the twitter users assessed twitter using the web, iphone, vine and tweetdeck. Most users used twitter for iphone. Also, a bar chart has been produced to illustrate this insights.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### The top five common type of dog are
# - The Golden retrieval
# - Labrador retriever
# - Pembroke
# - Chihuahua
# - Pug
#
# Also, not all the values are actually type of dogs. Some datas like nail, timber_wolf, desktop_computer are not type of dogs.

# %% [markdown]
# ###### From the analyis, the five common dog names are
# - Charlie
# - Lucy
# - Cooper
# - Oliver
# - Tucke
# ![image%202.png](attachment:image%202.png)
#
# Most of the dogs in our data had this names more frequently compared to other names.
